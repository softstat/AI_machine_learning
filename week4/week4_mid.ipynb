# %% [markdown]
# <a href="https://colab.research.google.com/github/softstat/AI_machine_learning/blob/main/week4/week4_mid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/long_data.csv
# Out:
# --2023-09-27 14:23:09--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/long_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5494 (5.4K) [text/plain]
# Saving to: ‘long_data.csv.1’
#
# long_data.csv.1     100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2023-09-27 14:23:09 (47.1 MB/s) - ‘long_data.csv.1’ saved [5494/5494]

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/wide_data.csv
# Out:
# --2023-09-27 14:23:10--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/wide_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 794 [text/plain]
# Saving to: ‘wide_data.csv.1’
#
# wide_data.csv.1     100%[===================>]     794  --.-KB/s    in 0s
#
# 2023-09-27 14:23:10 (38.5 MB/s) - ‘wide_data.csv.1’ saved [794/794]

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/dirty_data.csv
# Out:
# --2023-09-27 14:23:10--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/dirty_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46422 (45K) [text/plain]
# Saving to: ‘dirty_data.csv.1’
#
# dirty_data.csv.1    100%[===================>]  45.33K  --.-KB/s    in 0.01s
#
# 2023-09-27 14:23:10 (4.06 MB/s) - ‘dirty_data.csv.1’ saved [46422/46422]

# %%
import pandas as pd
import numpy as np

dirty = pd.read_csv("dirty_data.csv")
long = pd.read_csv("long_data.csv")
wide = pd.read_csv("wide_data.csv")

# %%
long.head(10)
# Out:
#   attributes datatype                 date            station  value
# 0   ,,H,0700     TMAX  2018-10-01T00:00:00  GHCND:USC00280907   21.1
# 1   ,,H,0700     TMIN  2018-10-01T00:00:00  GHCND:USC00280907    8.9
# 2   ,,H,0700     TOBS  2018-10-01T00:00:00  GHCND:USC00280907   13.9
# 3   ,,H,0700     TMAX  2018-10-02T00:00:00  GHCND:USC00280907   23.9
# 4   ,,H,0700     TMIN  2018-10-02T00:00:00  GHCND:USC00280907   13.9
# 5   ,,H,0700     TOBS  2018-10-02T00:00:00  GHCND:USC00280907   17.2
# 6   ,,H,0700     TMAX  2018-10-03T00:00:00  GHCND:USC00280907   25.0
# 7   ,,H,0700     TMIN  2018-10-03T00:00:00  GHCND:USC00280907   15.6
# 8   ,,H,0700     TOBS  2018-10-03T00:00:00  GHCND:USC00280907   16.1
# 9   ,,H,0700     TMAX  2018-10-04T00:00:00  GHCND:USC00280907   22.8

# %%
long.set_index('date').head(5)
# Out:
#                     attributes datatype            station  value
# date
# 2018-10-01T00:00:00   ,,H,0700     TMAX  GHCND:USC00280907   21.1
# 2018-10-01T00:00:00   ,,H,0700     TMIN  GHCND:USC00280907    8.9
# 2018-10-01T00:00:00   ,,H,0700     TOBS  GHCND:USC00280907   13.9
# 2018-10-02T00:00:00   ,,H,0700     TMAX  GHCND:USC00280907   23.9
# 2018-10-02T00:00:00   ,,H,0700     TMIN  GHCND:USC00280907   13.9

# %% [markdown]
# ### pivoting and unstack

# %%
long.columns
# Out:
# Index(['attributes', 'datatype', 'date', 'station', 'value'], dtype='object')

# %%
long_df = pd.read_csv(
    'long_data.csv', usecols=['date', 'datatype', 'value']
).rename(
    columns={'value': 'temp_C'}
).assign(
    date=lambda x: pd.to_datetime(x.date),
    temp_F=lambda x: (x.temp_C * 9/5) + 32
)

# %%
long_df.head(10)
# Out:
#   datatype       date  temp_C  temp_F
# 0     TMAX 2018-10-01    21.1   69.98
# 1     TMIN 2018-10-01     8.9   48.02
# 2     TOBS 2018-10-01    13.9   57.02
# 3     TMAX 2018-10-02    23.9   75.02
# 4     TMIN 2018-10-02    13.9   57.02
# 5     TOBS 2018-10-02    17.2   62.96
# 6     TMAX 2018-10-03    25.0   77.00
# 7     TMIN 2018-10-03    15.6   60.08
# 8     TOBS 2018-10-03    16.1   60.98
# 9     TMAX 2018-10-04    22.8   73.04

# %% [markdown]
# date를 인덱스로 고정 하고 long_df의 칼럼 중 'datatype'의 값을 가져온다

# %%
pivoted_df = long_df.pivot(index='date',columns='datatype',values='temp_C')
pivoted_df.head(10)
# Out:
# datatype    TMAX  TMIN  TOBS
# date
# 2018-10-01  21.1   8.9  13.9
# 2018-10-02  23.9  13.9  17.2
# 2018-10-03  25.0  15.6  16.1
# 2018-10-04  22.8  11.7  11.7
# 2018-10-05  23.3  11.7  18.9
# 2018-10-06  20.0  13.3  16.1
# 2018-10-07  20.0  16.1  20.0
# 2018-10-08  26.7  17.8  17.8
# 2018-10-09  18.9  17.2  17.8
# 2018-10-10  24.4  17.2  18.3

# %%
pivoted_df = long_df.pivot(index='date',columns='datatype',values=['temp_C','temp_F'])
pivoted_df.head()
# Out:
#            temp_C             temp_F
# datatype     TMAX  TMIN  TOBS   TMAX   TMIN   TOBS
# date
# 2018-10-01   21.1   8.9  13.9  69.98  48.02  57.02
# 2018-10-02   23.9  13.9  17.2  75.02  57.02  62.96
# 2018-10-03   25.0  15.6  16.1  77.00  60.08  60.98
# 2018-10-04   22.8  11.7  11.7  73.04  53.06  53.06
# 2018-10-05   23.3  11.7  18.9  73.94  53.06  66.02

# %% [markdown]
# ### Multi index를 이용해 'date'와 'datatype'을 index로 구성

# %%
multi_index_df = long_df.set_index(['date','datatype'])
multi_index_df.head().index
# Out:
# MultiIndex([('2018-10-01', 'TMAX'),
#             ('2018-10-01', 'TMIN'),
#             ('2018-10-01', 'TOBS'),
#             ('2018-10-02', 'TMAX'),
#             ('2018-10-02', 'TMIN')],
#            names=['date', 'datatype'])

# %%
multi_index_df.head()
# Out:
#                      temp_C  temp_F
# date       datatype
# 2018-10-01 TMAX        21.1   69.98
#            TMIN         8.9   48.02
#            TOBS        13.9   57.02
# 2018-10-02 TMAX        23.9   75.02
#            TMIN        13.9   57.02

# %%
unstacked_df = multi_index_df.unstack()
unstacked_df.head()
# Out:
#            temp_C             temp_F
# datatype     TMAX  TMIN  TOBS   TMAX   TMIN   TOBS
# date
# 2018-10-01   21.1   8.9  13.9  69.98  48.02  57.02
# 2018-10-02   23.9  13.9  17.2  75.02  57.02  62.96
# 2018-10-03   25.0  15.6  16.1  77.00  60.08  60.98
# 2018-10-04   22.8  11.7  11.7  73.04  53.06  53.06
# 2018-10-05   23.3  11.7  18.9  73.94  53.06  66.02

# %%
unstacked_df = pivoted_df.unstack()
unstacked_df
# Out:
#         datatype  date
# temp_C  TMAX      2018-10-01    21.10
#                   2018-10-02    23.90
#                   2018-10-03    25.00
#                   2018-10-04    22.80
#                   2018-10-05    23.30
#                                 ...
# temp_F  TOBS      2018-10-27    42.98
#                   2018-10-28    44.96
#                   2018-10-29    46.94
#                   2018-10-30    41.00
#                   2018-10-31    32.00
# Length: 186, dtype: float64

# %% [markdown]
# ### melting and stack

# %%
wide_df = pd.read_csv('wide_data.csv')
wide_df.head()
# Out:
#          date  TMAX  TMIN  TOBS
# 0  2018-10-01  21.1   8.9  13.9
# 1  2018-10-02  23.9  13.9  17.2
# 2  2018-10-03  25.0  15.6  16.1
# 3  2018-10-04  22.8  11.7  11.7
# 4  2018-10-05  23.3  11.7  18.9

# %% [markdown]
# ### melting and stack

# %%
melted_df = wide_df.melt(id_vars = 'date',
                         value_vars = ['TMAX','TMIN','TOBS'],
                         value_name = 'temp_C',var_name = 'measurement')
melted_df
# Out:
#           date measurement  temp_C
# 0   2018-10-01        TMAX    21.1
# 1   2018-10-02        TMAX    23.9
# 2   2018-10-03        TMAX    25.0
# 3   2018-10-04        TMAX    22.8
# 4   2018-10-05        TMAX    23.3
# ..         ...         ...     ...
# 88  2018-10-27        TOBS     6.1
# 89  2018-10-28        TOBS     7.2
# 90  2018-10-29        TOBS     8.3
# 91  2018-10-30        TOBS     5.0
# 92  2018-10-31        TOBS     0.0
#
# [93 rows x 3 columns]

# %%
wide_df.set_index('date',inplace=True)
stacked_series = wide_df.stack()
stacked_series.head()
# Out:
# date
# 2018-10-01  TMAX    21.1
#             TMIN     8.9
#             TOBS    13.9
# 2018-10-02  TMAX    23.9
#             TMIN    13.9
# dtype: float64

# %%
stacked_df = stacked_series.to_frame('values')
stacked_df.head()
# Out:
#                  values
# date
# 2018-10-01 TMAX    21.1
#            TMIN     8.9
#            TOBS    13.9
# 2018-10-02 TMAX    23.9
#            TMIN    13.9

# %% [markdown]
# ### problematic

# %%
df = pd.read_csv('dirty_data.csv')

# %%
contain_nulls = df[df.SNOW.isna()|df.SNWD.isna()|df.TOBS.isna()|df.WESF.isna()|df.inclement_weather.isna()]

# %%
contain_nulls.shape[0]
# Out:
# 765

# %% [markdown]
# ### NaN이 문자열이 아니기에 0을 출력한다

# %%
import numpy as np
df[df.inclement_weather == 'NaN'].shape[0] # No

df[df.inclement_weather ==np.NaN].shape[0] # No
# Out:
# 0

# %% [markdown]
# NA인 값의 개수

# %%
df[df.inclement_weather.isna()].shape[0]
# Out:
# 357

# %% [markdown]
# -inf +inf 개수

# %%
import numpy as np
df[df.SNWD.isin([-np.inf,np.inf])].shape[0]
# Out:
# 577

# %%
def get_inf_count(df):
    return {
        col : df[df[col].isin([np.inf,-np.inf])].shape[0] for col in df.columns
    }
get_inf_count(df)
# Out:
# {'date': 0,
#  'station': 0,
#  'PRCP': 0,
#  'SNOW': 0,
#  'SNWD': 577,
#  'TMAX': 0,
#  'TMIN': 0,
#  'TOBS': 0,
#  'WESF': 0,
#  'inclement_weather': 0}

# %% [markdown]
# 중복된 값이 있는 행 출력

# %%
df[df.duplicated()].shape[0]
# Out:
# 284

# %%
df[df.duplicated(keep='first')].shape[0]
# Out:
# 284

# %% [markdown]
# 무조건 중복이면 값 출력

# %%
df[df.duplicated(keep=False)].shape[0]
# Out:
# 482

# %%
df[df.duplicated()].head()
# Out:
#                   date            station  PRCP   SNOW  SNWD    TMAX  TMIN  \
# 1  2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 2  2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 5  2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 6  2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 8  2018-01-04T00:00:00                  ?  20.6  229.0   inf  5505.0 -40.0
#
#    TOBS  WESF inclement_weather
# 1   NaN   NaN               NaN
# 2   NaN   NaN               NaN
# 5 -13.3   NaN             False
# 6 -13.3   NaN             False
# 8   NaN  19.3              True

# %%
df.date = pd.to_datetime(df.date)

# %% [markdown]
# ### mitigating lssues part

# %%
station_qm_wesf = df[df.station=='?'].drop_duplicates('date').set_index('date').WESF

# %%
df.sort_values('station',ascending=False,inplace=True)

# %%
df_deduped = df.drop_duplicates('date')

# %%
df_deduped = df_deduped.drop(columns='station').set_index('date').sort_index()

# %%
df_deduped = df_deduped.assign(WESF = lambda x:x.WESF.combine_first(station_qm_wesf))

# %%
df_deduped.dropna(how="all").shape
# Out:
# (324, 8)

# %%
df_deduped.dropna(how='all',subset=['inclement_weather','SNOW','SNWD']).shape
# Out:
# (293, 8)

# %%
df_deduped.dropna(axis='columns',thresh=df_deduped.shape[0] *.75).columns
# Out:
# Index(['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN', 'TOBS', 'inclement_weather'], dtype='object')

# %%
df_deduped.loc[:,'WESF'].fillna(0,inplace=True)
df_deduped.head()
# Out:
#             PRCP   SNOW  SNWD    TMAX  TMIN  TOBS  WESF inclement_weather
# date
# 2018-01-01   0.0    0.0  -inf  5505.0 -40.0   NaN   0.0               NaN
# 2018-01-02   0.0    0.0  -inf    -8.3 -16.1 -12.2   0.0             False
# 2018-01-03   0.0    0.0  -inf    -4.4 -13.9 -13.3   0.0             False
# 2018-01-04  20.6  229.0   inf  5505.0 -40.0   NaN  19.3              True
# 2018-01-05  14.2  127.0   inf    -4.4 -13.9 -13.9   0.0              True

# %%
df_deduped = df_deduped.assign(TMAX = lambda x: x.TMAX.replace(5505,np.nan),
                               TMIN = lambda x: x.TMIN.replace(-40,np.nan))

# %%
df_deduped.assign(TMAX = lambda x: x.TMAX.fillna(method="ffill"),
                  TMIN = lambda x: x.TMIN.fillna(method="ffill")).head()
# Out:
#             PRCP   SNOW  SNWD  TMAX  TMIN  TOBS  WESF inclement_weather
# date
# 2018-01-01   0.0    0.0  -inf   NaN   NaN   NaN   0.0               NaN
# 2018-01-02   0.0    0.0  -inf  -8.3 -16.1 -12.2   0.0             False
# 2018-01-03   0.0    0.0  -inf  -4.4 -13.9 -13.3   0.0             False
# 2018-01-04  20.6  229.0   inf  -4.4 -13.9   NaN  19.3              True
# 2018-01-05  14.2  127.0   inf  -4.4 -13.9 -13.9   0.0              True

# %% [markdown]
# ### SNWD에 대해서 엄청나게 작거나 큰 값으로 -inf를 대체함

# %%
df_deduped.assign(SNWD = lambda x: np.nan_to_num(x.SNWD)).head()
# Out:
#             PRCP   SNOW           SNWD  TMAX  TMIN  TOBS  WESF  \
# date
# 2018-01-01   0.0    0.0 -1.797693e+308   NaN   NaN   NaN   0.0
# 2018-01-02   0.0    0.0 -1.797693e+308  -8.3 -16.1 -12.2   0.0
# 2018-01-03   0.0    0.0 -1.797693e+308  -4.4 -13.9 -13.3   0.0
# 2018-01-04  20.6  229.0  1.797693e+308   NaN   NaN   NaN  19.3
# 2018-01-05  14.2  127.0  1.797693e+308  -4.4 -13.9 -13.9   0.0
#
#            inclement_weather
# date
# 2018-01-01               NaN
# 2018-01-02             False
# 2018-01-03             False
# 2018-01-04              True
# 2018-01-05              True

# %% [markdown]
# ### SNOW 컬럼을 0으로 대체함

# %%
df_deduped.assign(SNWD = lambda x:x.SNWD.clip(0,x.SNOW)).head()
# Out:
#             PRCP   SNOW   SNWD  TMAX  TMIN  TOBS  WESF inclement_weather
# date
# 2018-01-01   0.0    0.0    0.0   NaN   NaN   NaN   0.0               NaN
# 2018-01-02   0.0    0.0    0.0  -8.3 -16.1 -12.2   0.0             False
# 2018-01-03   0.0    0.0    0.0  -4.4 -13.9 -13.3   0.0             False
# 2018-01-04  20.6  229.0  229.0   NaN   NaN   NaN  19.3              True
# 2018-01-05  14.2  127.0  127.0  -4.4 -13.9 -13.9   0.0              True

# %% [markdown]
# TMAX과 TMIN은 중앙값으로 대체하고 TOBS는 TMAX와 TMIN의 평균으로 대체

# %%
df_deduped.assign(
    TMAX = lambda x: x.TMAX.fillna(x.TMAX.median()),
    TMIN = lambda x: x.TMIN.fillna(x.TMIN.median()),
    TOBS = lambda x: x.TOBS.fillna((x.TMAX+x.TMIN)/2)
)
# Out:
#             PRCP   SNOW  SNWD  TMAX  TMIN  TOBS  WESF inclement_weather
# date
# 2018-01-01   0.0    0.0  -inf  14.4   5.6  10.0   0.0               NaN
# 2018-01-02   0.0    0.0  -inf  -8.3 -16.1 -12.2   0.0             False
# 2018-01-03   0.0    0.0  -inf  -4.4 -13.9 -13.3   0.0             False
# 2018-01-04  20.6  229.0   inf  14.4   5.6  10.0  19.3              True
# 2018-01-05  14.2  127.0   inf  -4.4 -13.9 -13.9   0.0              True
# ...          ...    ...   ...   ...   ...   ...   ...               ...
# 2018-12-27   0.0    0.0  -inf   5.6  -2.2  -1.1   0.0             False
# 2018-12-28  11.7    0.0  -inf   6.1  -1.7   5.0   0.0             False
# 2018-12-29  21.3    NaN   NaN  14.4   5.6  10.0   0.0               NaN
# 2018-12-30   0.0    NaN   NaN  14.4   5.6  10.0   0.0               NaN
# 2018-12-31   0.0    0.0  -inf   3.3  -3.3  -2.8   0.0             False
#
# [324 rows x 8 columns]
