# %% [markdown]
# <a href="https://colab.research.google.com/github/softstat/AI_machine_learning/blob/main/week2/exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
kim = {"Name":"김민석","Hobby":"walking and listening to music","Nationality":"Korea","student_id":18}
you = {"Name":"유태권","Hobby":"watching football","Nationality":"Korea","student_id":19}
jung = {"Name":"정민석","Hobby":"playing game","Nationality":"Korea","student_id":18}
jisoo = {"Name":"위지수","Hobby":"watching volleyball game","Nationality":"Korea","student_id":19}
lee = {"Name":"이주영","Hobby":"watching baseball","Nationality":"Korea","student_id":21}

# %%
team=pd.DataFrame([kim,you,jung,jisoo,lee])

# %%
team
# Out:
#   Name                           Hobby Nationality  student_id
# 0  김민석  walking and listening to music       Korea          18
# 1  유태권               watching football       Korea          19
# 2  정민석                    playing game       Korea          18
# 3  위지수        watching volleyball game       Korea          19
# 4  이주영               watching baseball       Korea          21

# %%
team.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
team.columns
# Out:
# Index(['Name', 'Hobby', 'Nationality', 'student_id'], dtype='object')

# %%
index = ["team2_mem1","team2_mem2","team2_mem3","team2_mem4","team2_mem5"]

# %%
new_data = pd.DataFrame([kim,you,jung,jisoo,lee],index=index)

# %%
new_data
# Out:
#            Name                           Hobby Nationality  student_id
# team2_mem1  김민석  walking and listening to music       Korea          18
# team2_mem2  유태권               watching football       Korea          19
# team2_mem3  정민석                    playing game       Korea          18
# team2_mem4  위지수        watching volleyball game       Korea          19
# team2_mem5  이주영               watching baseball       Korea          21

# %%
new_data.to_csv('exercise.csv',index=False)

# %%
call_data = pd.read_csv('exercise.csv')

# %%
call_data
# Out:
#   Name                           Hobby Nationality  student_id
# 0  김민석  walking and listening to music       Korea          18
# 1  유태권               watching football       Korea          19
# 2  정민석                    playing game       Korea          18
# 3  위지수        watching volleyball game       Korea          19
# 4  이주영               watching baseball       Korea          21

# %%
call_data.describe()
# Out:
#        student_id
# count    5.000000
# mean    19.000000
# std      1.224745
# min     18.000000
# 25%     18.000000
# 50%     19.000000
# 75%     19.000000
# max     21.000000

# %%
call_data.value_counts()
# Out:
# Name  Hobby                           Nationality  student_id
# 김민석   walking and listening to music  Korea        18            1
# 위지수   watching volleyball game        Korea        19            1
# 유태권   watching football               Korea        19            1
# 이주영   watching baseball               Korea        21            1
# 정민석   playing game                    Korea        18            1
# dtype: int64

# %%
call_data[1:]
# Out:
#   Name                     Hobby Nationality  student_id
# 1  유태권         watching football       Korea          19
# 2  정민석              playing game       Korea          18
# 3  위지수  watching volleyball game       Korea          19
# 4  이주영         watching baseball       Korea          21
