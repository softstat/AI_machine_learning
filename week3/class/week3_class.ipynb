# %% [markdown]
# <a href="https://colab.research.google.com/github/softstat/AI_machine_learning/blob/main/week3/class/week3_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd Hands-On-Data-Analysis-with-Pandas-2nd-edition/
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition

# %%
cd ch_02/data/
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02/data

# %% [markdown]
# ## Load earthquakes data from ch2 code

# %%
import pandas as pd
df = pd.read_csv('earthquakes.csv')

# %% [markdown]
# ### Try loc and iloc

# %%
df.loc[3:10]
# Out:
#    alert  cdi        code                                             detail  \
# 3    NaN  NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4    NaN  NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5    NaN  NaN  2018286011  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 6    NaN  NaN    20280432  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7    NaN  NaN    73096936  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8    NaN  NaN    73096931  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9    NaN  NaN    1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 10   NaN  NaN    37389162  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap             ids   mag magType  ...  sources  \
# 3   0.026180   NaN   39.0    ,ci37389186,  0.44      ml  ...     ,ci,
# 4   0.077990   NaN  192.0    ,nc73096941,  2.16      md  ...     ,nc,
# ...

# %%
df.loc[3:10,['mag','magType','type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
df.iloc[3:11,[8,9,10,11]]
# Out:
#      mag magType  mmi net
# 3   0.44      ml  NaN  ci
# 4   2.16      md  NaN  nc
# 5   2.61      md  NaN  pr
# 6   1.70      ml  NaN  ak
# 7   1.13      md  NaN  nc
# 8   0.92      md  NaN  nc
# 9   4.70      mb  NaN  us
# 10  0.50      ml  NaN  ci

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %% [markdown]
# ### Try to find items of location Arizona

# %%
df[df.place.str.contains('Arizona')]
# Out:
#      alert  cdi      code                                             detail  \
# 1062   NaN  NaN  60300227  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3965   NaN  NaN  60298572  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...  sources    status  \
# 1062  0.1666   NaN  163.0  ,uu60300227,  1.23      ml  ...     ,uu,  reviewed
# 3965  0.1577   NaN  211.0  ,uu60298572,  0.94      md  ...     ,uu,  reviewed
#
#                time                                      title  tsunami  \
# 1062  1539133978610  M 1.2 - 7km SSW of Colorado City, Arizona        0
# 3965  1538383710020  M 0.9 - 7km WSW of Colorado City, Arizona        0
#
#             type                         types     tz        updated  \
# 1062  earthquake  ,geoserve,origin,phase-data, -420.0  1539196068710
# 3965  earthquake  ,geoserve,origin,phase-data, -420.0  1538516934720
#
#                                                     url
# ...

# %% [markdown]
# ### Try to find 10 largest items of mag variable

# %%
df.sort_values(by='mag',ascending=False).head(10)
# Out:
#       alert  cdi      code                                             detail  \
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4363  green  2.2  1000h4l1  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118   green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 799   green  NaN  1000hacw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 816   green  NaN  1000habl  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 838   green  NaN  1000ha9t  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5323  green  NaN  1000h3mf  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9211  green  NaN  2000hg93  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 862   green  4.3  1000ha6q  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin   felt   gap                                 ids  mag magType  \
# ...

# %% [markdown]
# ### Try to delete alert variable

# %%
del(df['alert'])

# %% [markdown]
# ### Try to pop mag and magType variables one at a time with name mag and magType

# %%
df_mag = df.pop('mag')
df_magType = df.pop('magType')

# %%
df_mag
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
df_magType
# Out:
# 0       ml
# 1       ml
# 2       ml
# 3       ml
# 4       md
#         ..
# 9327    md
# 9328    ml
# 9329    md
# 9330    ml
# 9331    ml
# Name: magType, Length: 9332, dtype: object

# %% [markdown]
# ### Concatenate mag and magType variables and define

# %%
df_plus = pd.concat([df_mag,df_magType],axis=1)
df_plus
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]

# %%
df = pd.read_csv('earthquakes.csv')
df_mag = df['mag'].pop
df_magType = df['magType'].pop

# %%
df_mag
# Out:
# <bound method Series.pop of 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64>
